-- %%
require 'image';

-- %%
rootdir = '/scratch/jmj/dgm_maxout40/'
mean_probs = {}
mean_probs['baseline'] = torch.load(paths.concat(rootdir,'save_baseline/mean_probs.t7'))
mean_probs['planarflow1'] = torch.load(paths.concat(rootdir,'save_planarflow1/mean_probs.t7'))
mean_probs['planarflow1deep'] = torch.load(paths.concat(rootdir,'save_planarflow1deep/mean_probs.t7'))
mean_probs['planarflow5deep'] = torch.load(paths.concat(rootdir,'save_planarflow5deep/mean_probs.t7'))
mean_probs['planarflow5deep_annealed'] = torch.load(paths.concat(rootdir,'save_planarflow5deep_annealed/mean_probs.t7'))
mean_probs['planarflow5deep_dropout'] = torch.load(paths.concat(rootdir,'save_planarflow5deep_dropout/mean_probs.t7'))
mean_probs['planarflow20deep'] = torch.load(paths.concat(rootdir,'save_planarflow20deep/mean_probs.t7'))

-- %%
for i,ims in pairs(mean_probs) do
    print(i)
    itorch.image(image.toDisplayTensor{input=ims,nrow=25})
end
-- Out:
-- baseline
-- Console does not support images
-- planarflow5deep_dropout
-- planarflow20deep
-- Console does not support images
-- Console does not support images
-- planarflow1deep
-- Console does not support images
-- planarflow5deep
-- Console does not support images
-- planarflow5deep_annealed
-- Console does not support images
-- planarflow1
-- Console does not support images
